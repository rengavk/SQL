# %%
import pandas as _hex_pandas
import datetime as _hex_datetime
import json as _hex_json

# %%
hex_scheduled = _hex_json.loads("false")

# %%
hex_user_email = _hex_json.loads("\"example-user@example.com\"")

# %%
hex_user_attributes = _hex_json.loads("{}")

# %%
hex_run_context = _hex_json.loads("\"logic\"")

# %%
hex_timezone = _hex_json.loads("\"UTC\"")

# %%
hex_project_id = _hex_json.loads("\"01994dfb-7271-7000-82c2-9f4879c31a69\"")

# %%
hex_project_name = _hex_json.loads("\"Sales dataset\"")

# %%
hex_status = _hex_json.loads("\"\"")

# %%
hex_categories = _hex_json.loads("[]")

# %%
hex_color_palette = _hex_json.loads("[\"#4C78A8\",\"#F58518\",\"#E45756\",\"#72B7B2\",\"#54A24B\",\"#EECA3B\",\"#B279A2\",\"#FF9DA6\",\"#9D755D\",\"#BAB0AC\"]")

# %%
# import jinja2
# raw_query = """
#     SELECT
#         *
#     FROM "customers.csv";
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
# import jinja2
# raw_query = """
#     select * from "orders.csv";
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
# import jinja2
# raw_query = """
#     SELECT
#         order_id,
#         customer_id,
#         product_name
#     FROM
#         orders
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
# import jinja2
# raw_query = """
#     SELECT
#         *
#     FROM
#         orders
#     ORDER BY
#         order_date DESC
#     
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
# import jinja2
# raw_query = """
#     select
#         distinct order_id
#     from
#         orders
#     
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
# import jinja2
# raw_query = """
#     select
#         distinct customer_id
#     from
#         orders
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
# import jinja2
# raw_query = """
#     select
#         distinct product_name
#     from
#         orders
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
# import jinja2
# raw_query = """
#     select 
#         order_date,
#         count(order_id) as number_orders
#     from 
#         orders
#     group by 
#         1;
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
# import jinja2
# raw_query = """
#     -- total revenue
#     SELECT ROUND(SUM(quantity * price),2) AS total_revenue FROM orders;
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
# import jinja2
# raw_query = """
#     -- average order value (AOV)
#     WITH order_totals AS (
#       SELECT order_id, SUM(quantity*price) AS order_value
#       FROM orders
#       GROUP BY order_id
#     )
#     SELECT ROUND(AVG(order_value),2) AS avg_order_value
#     FROM order_totals;
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
import altair
chart_dataframe_7 = altair.Chart.from_json(r"""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [],
    "config": {
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    }
}
""")
chart_dataframe_7.datasets.layer00 = dataframe_7.to_json(orient='records')
chart_dataframe_7.display(actions=False)

# %% [markdown]
# Orders & Revenue by month

# %%
# import jinja2
# raw_query = """
#     SELECT strftime('%Y-%m', order_date) AS order_month,
#            COUNT(DISTINCT order_id) AS orders,
#            ROUND(SUM(quantity*price),2) AS revenue
#     FROM orders
#     GROUP BY order_month
#     ORDER BY order_month;
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %% [markdown]
# Top Products

# %%
# import jinja2
# raw_query = """
#     SELECT product_name,
#            COUNT(DISTINCT order_id) AS orders,
#            SUM(quantity) AS units,
#            ROUND(SUM(quantity*price),2) AS revenue
#     FROM orders
#     GROUP BY product_name
#     ORDER BY revenue DESC
#     LIMIT 10;
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
import altair
chart_dataframe_10 = altair.Chart.from_json(r"""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "description": "outer data layer",
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "description": "series data layer",
                    "name": "series_0199739c-6982-7ddf-886c-40a4717ed283",
                    "layer": [
                        {
                            "description": "bar series layer",
                            "transform": [
                                {
                                    "joinaggregate": [
                                        {
                                            "field": "orders",
                                            "op": "sum",
                                            "as": "sum_y_by_x"
                                        }
                                    ],
                                    "groupby": [
                                        "product_name"
                                    ]
                                },
                                {
                                    "calculate": "datum[\"orders\"] / datum[\"sum_y_by_x\"]",
                                    "as": "PCT_OF_X"
                                }
                            ],
                            "layer": [
                                {
                                    "description": "bar mark layer",
                                    "mark": {
                                        "type": "bar",
                                        "clip": true,
                                        "filled": true,
                                        "cursor": "pointer",
                                        "orient": "vertical"
                                    },
                                    "encoding": {
                                        "opacity": {
                                            "value": 1
                                        },
                                        "tooltip": [
                                            {
                                                "field": "product_name",
                                                "type": "ordinal",
                                                "format": {
                                                    "year": "%Y",
                                                    "quarter": "%b %d",
                                                    "month": "%b %d",
                                                    "week": "%b %d",
                                                    "day": "%b %d"
                                                },
                                                "title": "product_name"
                                            },
                                            {
                                                "field": "orders",
                                                "type": "quantitative",
                                                "aggregate": "sum",
                                                "formatType": "NUMBER_FORMATTER",
                                                "format": {
                                                    "format": "NUMBER",
                                                    "columnType": "NUMBER",
                                                    "numDecimalDigits": -1,
                                                    "currency": "USD",
                                                    "nanFormat": ""
                                                },
                                                "title": "Sum of orders"
                                            }
                                        ],
                                        "color": {
                                            "value": "#4C78A8"
                                        },
                                        "x": {
                                            "field": "product_name",
                                            "type": "ordinal",
                                            "title": "product_name",
                                            "scale": {},
                                            "axis": {
                                                "grid": true,
                                                "ticks": true,
                                                "labels": true,
                                                "labelFlush": false,
                                                "format": {
                                                    "year": "%Y",
                                                    "quarter": "%b %d",
                                                    "month": "%b %d",
                                                    "week": "%b %d",
                                                    "day": "%b %d"
                                                },
                                                "labelOverlap": "greedy"
                                            }
                                        },
                                        "y": {
                                            "field": "orders",
                                            "type": "quantitative",
                                            "aggregate": "sum",
                                            "title": "Sum of orders",
                                            "scale": {},
                                            "axis": {
                                                "grid": true,
                                                "ticks": true,
                                                "labels": true,
                                                "labelFlush": false,
                                                "format": {
                                                    "format": "NUMBER",
                                                    "columnType": "NUMBER",
                                                    "numDecimalDigits": -1,
                                                    "currency": "USD",
                                                    "nanFormat": ""
                                                },
                                                "formatType": "NUMBER_FORMATTER"
                                            },
                                            "stack": "zero"
                                        }
                                    }
                                }
                            ],
                            "encoding": {
                                "x": {
                                    "field": "product_name",
                                    "type": "ordinal",
                                    "title": "product_name",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "labels": true,
                                        "labelFlush": false,
                                        "format": {
                                            "year": "%Y",
                                            "quarter": "%b %d",
                                            "month": "%b %d",
                                            "week": "%b %d",
                                            "day": "%b %d"
                                        },
                                        "labelOverlap": "greedy"
                                    }
                                },
                                "y": {
                                    "field": "orders",
                                    "type": "quantitative",
                                    "aggregate": "sum",
                                    "title": "Sum of orders",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "labels": true,
                                        "labelFlush": false,
                                        "format": {
                                            "format": "NUMBER",
                                            "columnType": "NUMBER",
                                            "numDecimalDigits": -1,
                                            "currency": "USD",
                                            "nanFormat": ""
                                        },
                                        "formatType": "NUMBER_FORMATTER"
                                    },
                                    "stack": "zero"
                                }
                            }
                        }
                    ]
                }
            ],
            "transform": []
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {},
        "columnNameMappings": {
            "CHART_FOLD_KEYS": "Y-Axis Field",
            "CHART_FOLD_VALUES": "Values"
        }
    }
}
""")
chart_dataframe_10.datasets.layer00 = dataframe_10.to_json(orient='records')
chart_dataframe_10.display(actions=False)

# %% [markdown]
# Revenue by State

# %%
# import jinja2
# raw_query = """
#     SELECT c.state,
#            COUNT(DISTINCT o.order_id) AS orders,
#            ROUND(SUM(o.quantity*o.price),2) AS revenue
#     FROM orders o
#     JOIN customers c ON c.id = o.customer_id
#     GROUP BY c.state
#     ORDER BY revenue DESC;
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
import altair
chart_dataframe_11 = altair.Chart.from_json(r"""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "description": "outer data layer",
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "description": "series data layer",
                    "name": "series_0199739c-1f0e-7ddf-886b-2f5581f31755",
                    "layer": [
                        {
                            "description": "bar series layer",
                            "transform": [
                                {
                                    "joinaggregate": [
                                        {
                                            "field": "orders",
                                            "op": "sum",
                                            "as": "sum_y_by_x"
                                        }
                                    ],
                                    "groupby": [
                                        "state"
                                    ]
                                },
                                {
                                    "calculate": "datum[\"orders\"] / datum[\"sum_y_by_x\"]",
                                    "as": "PCT_OF_X"
                                }
                            ],
                            "layer": [
                                {
                                    "description": "bar mark layer",
                                    "mark": {
                                        "type": "bar",
                                        "clip": true,
                                        "filled": true,
                                        "cursor": "pointer",
                                        "orient": "vertical"
                                    },
                                    "params": [
                                        {
                                            "name": "interval_intervalselection_0",
                                            "select": {
                                                "type": "interval",
                                                "encodings": [
                                                    "x"
                                                ],
                                                "mark": {
                                                    "fill": "#669EFF",
                                                    "fillOpacity": 0.07,
                                                    "stroke": "#669EFF",
                                                    "strokeOpacity": 0.4
                                                },
                                                "zoom": false
                                            }
                                        },
                                        {
                                            "name": "click_pointselection_0",
                                            "select": {
                                                "type": "point",
                                                "encodings": [
                                                    "x",
                                                    "color"
                                                ],
                                                "toggle": "false"
                                            }
                                        },
                                        {
                                            "name": "legend_pointselection_0",
                                            "select": {
                                                "type": "point",
                                                "encodings": [
                                                    "color"
                                                ]
                                            },
                                            "bind": "legend"
                                        },
                                        {
                                            "name": "legend_pointhover_0",
                                            "select": {
                                                "type": "point",
                                                "encodings": [
                                                    "color"
                                                ]
                                            },
                                            "bind": "legend"
                                        }
                                    ],
                                    "encoding": {
                                        "opacity": {
                                            "condition": {
                                                "test": {
                                                    "not": {
                                                        "and": [
                                                            {
                                                                "param": "interval_intervalselection_0"
                                                            },
                                                            {
                                                                "param": "click_pointselection_0"
                                                            },
                                                            {
                                                                "or": [
                                                                    {
                                                                        "param": "legend_pointselection_0",
                                                                        "empty": false
                                                                    },
                                                                    {
                                                                        "param": "legend_pointhover_0"
                                                                    }
                                                                ]
                                                            }
                                                        ]
                                                    }
                                                },
                                                "value": 0.3
                                            },
                                            "value": 1
                                        },
                                        "tooltip": [
                                            {
                                                "field": "state",
                                                "type": "ordinal",
                                                "format": {
                                                    "year": "%Y",
                                                    "quarter": "%b %d",
                                                    "month": "%b %d",
                                                    "week": "%b %d",
                                                    "day": "%b %d"
                                                },
                                                "title": "state"
                                            },
                                            {
                                                "field": "orders",
                                                "type": "quantitative",
                                                "aggregate": "sum",
                                                "formatType": "NUMBER_FORMATTER",
                                                "format": {
                                                    "format": "NUMBER",
                                                    "columnType": "NUMBER",
                                                    "numDecimalDigits": -1,
                                                    "currency": "USD",
                                                    "nanFormat": ""
                                                },
                                                "title": "Sum of orders"
                                            },
                                            {
                                                "field": "state",
                                                "type": "ordinal",
                                                "title": "state"
                                            }
                                        ],
                                        "color": {
                                            "field": "state",
                                            "scale": {
                                                "range": [
                                                    "#4C78A8",
                                                    "#F58518",
                                                    "#E45756",
                                                    "#72B7B2",
                                                    "#54A24B",
                                                    "#EECA3B",
                                                    "#B279A2",
                                                    "#FF9DA6",
                                                    "#9D755D",
                                                    "#BAB0AC"
                                                ]
                                            },
                                            "sort": {
                                                "field": "state",
                                                "order": "ascending"
                                            },
                                            "legend": {
                                                "symbolOpacity": 1
                                            },
                                            "title": "state"
                                        },
                                        "order": {
                                            "field": "state",
                                            "sort": "descending"
                                        },
                                        "x": {
                                            "field": "state",
                                            "type": "ordinal",
                                            "title": "state",
                                            "scale": {},
                                            "axis": {
                                                "grid": true,
                                                "ticks": true,
                                                "labels": true,
                                                "labelFlush": false,
                                                "format": {
                                                    "year": "%Y",
                                                    "quarter": "%b %d",
                                                    "month": "%b %d",
                                                    "week": "%b %d",
                                                    "day": "%b %d"
                                                },
                                                "labelOverlap": "greedy"
                                            }
                                        },
                                        "y": {
                                            "field": "orders",
                                            "type": "quantitative",
                                            "aggregate": "sum",
                                            "title": "Sum of orders",
                                            "scale": {},
                                            "axis": {
                                                "grid": true,
                                                "ticks": true,
                                                "labels": true,
                                                "labelFlush": false,
                                                "format": {
                                                    "format": "NUMBER",
                                                    "columnType": "NUMBER",
                                                    "numDecimalDigits": -1,
                                                    "currency": "USD",
                                                    "nanFormat": ""
                                                },
                                                "formatType": "NUMBER_FORMATTER"
                                            },
                                            "stack": "zero"
                                        }
                                    }
                                }
                            ],
                            "encoding": {
                                "x": {
                                    "field": "state",
                                    "type": "ordinal",
                                    "title": "state",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "labels": true,
                                        "labelFlush": false,
                                        "format": {
                                            "year": "%Y",
                                            "quarter": "%b %d",
                                            "month": "%b %d",
                                            "week": "%b %d",
                                            "day": "%b %d"
                                        },
                                        "labelOverlap": "greedy"
                                    }
                                },
                                "y": {
                                    "field": "orders",
                                    "type": "quantitative",
                                    "aggregate": "sum",
                                    "title": "Sum of orders",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "labels": true,
                                        "labelFlush": false,
                                        "format": {
                                            "format": "NUMBER",
                                            "columnType": "NUMBER",
                                            "numDecimalDigits": -1,
                                            "currency": "USD",
                                            "nanFormat": ""
                                        },
                                        "formatType": "NUMBER_FORMATTER"
                                    },
                                    "stack": "zero"
                                }
                            }
                        }
                    ]
                }
            ],
            "transform": []
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {
            "interval_intervalselection_0": {
                "type": "interval",
                "datetimeFields": [],
                "derived": []
            },
            "click_pointselection_0": {
                "type": "point",
                "datetimeFields": [],
                "derived": []
            },
            "legend_pointselection_0": {
                "type": "point",
                "datetimeFields": [],
                "derived": []
            }
        },
        "columnNameMappings": {
            "CHART_FOLD_KEYS": "Y-Axis Field",
            "CHART_FOLD_VALUES": "Values"
        }
    }
}
""")
chart_dataframe_11.datasets.layer00 = dataframe_11.to_json(orient='records')
chart_dataframe_11.display(actions=False)

# %% [markdown]
# coupon impact on AOV

# %%
# import jinja2
# raw_query = """
#     WITH order_totals AS (
#       SELECT order_id,
#              COALESCE(MAX(coupon),0) AS coupon_used,
#              SUM(quantity*price) AS order_value
#       FROM orders
#       GROUP BY order_id
#     )
#     SELECT CASE WHEN coupon_used IS NULL OR coupon_used=0
#                 THEN 'No Coupon' ELSE 'Coupon' END AS coupon_flag,
#            COUNT(*) AS orders,
#            ROUND(AVG(order_value),2) AS avg_order_value
#     FROM order_totals
#     GROUP BY coupon_flag;
# """
# sql_query = jinja2.Template(raw_query).render(vars())

# %%
import altair
chart_dataframe_12 = altair.Chart.from_json(r"""
{
    "width": "container",
    "height": "container",
    "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
    "layer": [
        {
            "description": "outer data layer",
            "resolve": {
                "scale": {
                    "color": "independent",
                    "y": "shared"
                }
            },
            "layer": [
                {
                    "description": "series data layer",
                    "name": "series_0199739b-dca9-7ddf-886a-41269013a81f",
                    "layer": [
                        {
                            "description": "bar series layer",
                            "transform": [
                                {
                                    "joinaggregate": [
                                        {
                                            "field": "orders",
                                            "op": "sum",
                                            "as": "sum_y_by_x"
                                        }
                                    ],
                                    "groupby": [
                                        "coupon_flag"
                                    ]
                                },
                                {
                                    "calculate": "datum[\"orders\"] / datum[\"sum_y_by_x\"]",
                                    "as": "PCT_OF_X"
                                }
                            ],
                            "layer": [
                                {
                                    "description": "bar mark layer",
                                    "mark": {
                                        "type": "bar",
                                        "clip": true,
                                        "filled": true,
                                        "cursor": "pointer",
                                        "orient": "vertical"
                                    },
                                    "params": [
                                        {
                                            "name": "interval_intervalselection_0",
                                            "select": {
                                                "type": "interval",
                                                "encodings": [
                                                    "x"
                                                ],
                                                "mark": {
                                                    "fill": "#669EFF",
                                                    "fillOpacity": 0.07,
                                                    "stroke": "#669EFF",
                                                    "strokeOpacity": 0.4
                                                },
                                                "zoom": false
                                            }
                                        },
                                        {
                                            "name": "click_pointselection_0",
                                            "select": {
                                                "type": "point",
                                                "encodings": [
                                                    "x"
                                                ]
                                            }
                                        }
                                    ],
                                    "encoding": {
                                        "opacity": {
                                            "condition": {
                                                "test": {
                                                    "not": {
                                                        "and": [
                                                            {
                                                                "param": "interval_intervalselection_0"
                                                            },
                                                            {
                                                                "param": "click_pointselection_0"
                                                            }
                                                        ]
                                                    }
                                                },
                                                "value": 0.3
                                            },
                                            "value": 1
                                        },
                                        "tooltip": [
                                            {
                                                "field": "coupon_flag",
                                                "type": "ordinal",
                                                "format": {
                                                    "year": "%Y",
                                                    "quarter": "%b %d",
                                                    "month": "%b %d",
                                                    "week": "%b %d",
                                                    "day": "%b %d"
                                                },
                                                "title": "coupon_flag"
                                            },
                                            {
                                                "field": "orders",
                                                "type": "quantitative",
                                                "aggregate": "sum",
                                                "formatType": "NUMBER_FORMATTER",
                                                "format": {
                                                    "format": "NUMBER",
                                                    "columnType": "NUMBER",
                                                    "numDecimalDigits": -1,
                                                    "currency": "USD",
                                                    "nanFormat": ""
                                                },
                                                "title": "Sum of orders"
                                            }
                                        ],
                                        "color": {
                                            "value": "#4C78A8"
                                        },
                                        "x": {
                                            "field": "coupon_flag",
                                            "type": "ordinal",
                                            "title": "coupon_flag",
                                            "scale": {},
                                            "axis": {
                                                "grid": true,
                                                "ticks": true,
                                                "labels": true,
                                                "labelFlush": false,
                                                "format": {
                                                    "year": "%Y",
                                                    "quarter": "%b %d",
                                                    "month": "%b %d",
                                                    "week": "%b %d",
                                                    "day": "%b %d"
                                                },
                                                "labelOverlap": "greedy"
                                            }
                                        },
                                        "y": {
                                            "field": "orders",
                                            "type": "quantitative",
                                            "aggregate": "sum",
                                            "title": "Sum of orders",
                                            "scale": {},
                                            "axis": {
                                                "grid": true,
                                                "ticks": true,
                                                "labels": true,
                                                "labelFlush": false,
                                                "format": {
                                                    "format": "NUMBER",
                                                    "columnType": "NUMBER",
                                                    "numDecimalDigits": -1,
                                                    "currency": "USD",
                                                    "nanFormat": ""
                                                },
                                                "formatType": "NUMBER_FORMATTER"
                                            },
                                            "stack": "zero"
                                        }
                                    }
                                }
                            ],
                            "encoding": {
                                "x": {
                                    "field": "coupon_flag",
                                    "type": "ordinal",
                                    "title": "coupon_flag",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "labels": true,
                                        "labelFlush": false,
                                        "format": {
                                            "year": "%Y",
                                            "quarter": "%b %d",
                                            "month": "%b %d",
                                            "week": "%b %d",
                                            "day": "%b %d"
                                        },
                                        "labelOverlap": "greedy"
                                    }
                                },
                                "y": {
                                    "field": "orders",
                                    "type": "quantitative",
                                    "aggregate": "sum",
                                    "title": "Sum of orders",
                                    "scale": {},
                                    "axis": {
                                        "grid": true,
                                        "ticks": true,
                                        "labels": true,
                                        "labelFlush": false,
                                        "format": {
                                            "format": "NUMBER",
                                            "columnType": "NUMBER",
                                            "numDecimalDigits": -1,
                                            "currency": "USD",
                                            "nanFormat": ""
                                        },
                                        "formatType": "NUMBER_FORMATTER"
                                    },
                                    "stack": "zero"
                                }
                            }
                        }
                    ]
                }
            ],
            "transform": []
        }
    ],
    "config": {
        "legend": {
            "orient": "right"
        },
        "font": "\"IBM Plex Sans\", system-ui, -apple-system, BlinkMacSystemFont, sans-serif",
        "view": {}
    },
    "datasets": {
        "layer00": [
            {
                "name": "dummy",
                "value": 0
            }
        ]
    },
    "usermeta": {
        "selectionConfigs": {
            "interval_intervalselection_0": {
                "type": "interval",
                "datetimeFields": [],
                "derived": []
            },
            "click_pointselection_0": {
                "type": "point",
                "datetimeFields": [],
                "derived": []
            }
        },
        "columnNameMappings": {
            "CHART_FOLD_KEYS": "Y-Axis Field",
            "CHART_FOLD_VALUES": "Values"
        }
    }
}
""")
chart_dataframe_12.datasets.layer00 = dataframe_12.to_json(orient='records')
chart_dataframe_12.display(actions=False)

# %% [markdown]
# Payment method

# %%
# import jinja2
# raw_query = """
#     SELECT payment_method,
#            COUNT(DISTINCT order_id) AS orders,
#            ROUND(SUM(quantity*price),2) AS revenue
#     FROM orders
#     GROUP BY payment_method
#     ORDER BY orders DESC;
# """
# sql_query = jinja2.Template(raw_query).render(vars())
